# %%
# %cd yolov5
# Out:
# C:\Users\15652\Desktop\comp9517\group project\yolov5

# %%
# %pip install --user -qr requirements.txt

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5  2022-11-4 Python-3.9.13 torch-1.8.0+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# Setup complete  (8 CPUs, 15.9 GB RAM, 391.3/475.7 GB disk)

# %%
# !python train.py --batch 32 --epochs 10 --data ../yolotrain/data.yaml --cfg models/yolov5s.yaml
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=../yolotrain/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 14 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to 'C:\Users\15652\Desktop\comp9517\group': No such file or directory
# YOLOv5  2022-11-4 Python-3.9.13 torch-1.8.0+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# ...

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !python detect.py --weight runs\train\exp5\weights\best.pt --source ../yolotrain/test/images --save-txt
# Out:
# detect: weights=['runs\\train\\exp5\\weights\\best.pt'], source=../yolotrain/test/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\15652\Desktop\comp9517\group': No such file or directory
# YOLOv5  2022-11-4 Python-3.9.13 torch-1.8.0+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/492 C:\Users\15652\Desktop\comp9517\group project\yolotrain\test\images\0-1007_jpg.rf.122bd536b1c919a281abe78051fde020.jpg: 640x640 1 starfish, 11.0ms
# ...

# %%
# !python val.py --data ../yolotrain/data.yaml --weight runs\train\exp5\weights\best.pt --img 640
# Out:
# val: data=../yolotrain/data.yaml, weights=['runs\\train\\exp5\\weights\\best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\15652\Desktop\comp9517\group': No such file or directory
# YOLOv5  2022-11-4 Python-3.9.13 torch-1.8.0+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# val: Scanning 'C:\Users\15652\Desktop\comp9517\group project\yolotrain\valid\labels' images and labels...:   0%|          | 0/211 [00:00<?, ?it/s]
# val: Scanning 'C:\Users\15652\Desktop\comp9517\group project\yolotrain\valid\labels' images and labels...1 found, 0 missing, 0 empty, 0 corrupt:   0%|          | 1/211 [00:05<20:16,  5.79s/it]
# ...
